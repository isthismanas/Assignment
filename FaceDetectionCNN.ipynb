# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import tensorflow as tf
import sklearn
import glob

# %% [markdown]
# ## Data Pipeline

# %%
AkshayKumarfilepaths = glob.glob('dataset\Faces\Original Images\Original Images\Akshay Kumar\*.jpg') +glob.glob('dataset\Faces\Faces\Faces\Akshay Kumar_*.jpg')
Alexandrafilepaths = glob.glob('dataset\Faces\Original Images\Original Images\Alexandra Daddario\*.jpg') + glob.glob('dataset\Faces\Faces\Faces\Alexandra Daddario_*.jpg')
AliaBhattfilepaths = glob.glob('dataset\Faces\Original Images\Original Images\Alia Bhatt\*.jpg') + glob.glob('dataset\Faces\Faces\Faces\Alia Bhatt_*.jpg')
Courtneyfilepaths = glob.glob('dataset\Faces\Original Images\Original Images\Courtney Cox\*.jpg') + glob.glob('dataset\Faces\Faces\Faces\Courtney Cox_*.jpg')

# %%
AkshayKumarFDataset = tf.data.Dataset.from_tensor_slices(AkshayKumarfilepaths)
AlexandraFDataset = tf.data.Dataset.from_tensor_slices(Alexandrafilepaths)
AliaDataset = tf.data.Dataset.from_tensor_slices(AliaBhattfilepaths)
CourtneyDataset = tf.data.Dataset.from_tensor_slices(Courtneyfilepaths)

# %%
def preprocess_images(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels = 3)
    img = tf.cast(img , tf.float32) / 255.0
    img = tf.image.resize_with_pad(img , 250 ,250 )
    return img

data_augmentation = tf.keras.Sequential([tf.keras.layers.RandomFlip(mode = 'horizontal' , seed = 42),
                                         tf.keras.layers.RandomRotation(factor = 0.05, seed = 42),
                                         tf.keras.layers.RandomContrast(factor = 0.2, seed = 42)])

# %%
AkhshayTensor = tf.TensorArray(tf.float32, size = 0, dynamic_size = True )
AlexandraTensor = tf.TensorArray(tf.float32, size = 0 , dynamic_size = True)
AliaTensor = tf.TensorArray(tf.float32, size = 0, dynamic_size= True)
CourtneyTensor = tf.TensorArray(tf.float32, size = 0, dynamic_size = True)

# %%
AkshayKumarFDataset = AkshayKumarFDataset.map(preprocess_images)
AlexandraFDataset = AlexandraFDataset.map(preprocess_images)
AliaDataset = AliaDataset.map(preprocess_images)
CourtneyDataset = CourtneyDataset.map(preprocess_images)

# %%
for img in AkshayKumarFDataset:
    AkhshayTensor = AkhshayTensor.write(AkhshayTensor.size(), img)
for img in AlexandraFDataset:
    AlexandraTensor = AlexandraTensor.write(AlexandraTensor.size(), img)
for img in AliaDataset:
    AliaTensor = AliaTensor.write(AliaTensor.size(), img)
for img in CourtneyDataset:
    CourtneyTensor = CourtneyTensor.write(CourtneyTensor.size(), img)

# %%
AkhshayTensor = AkhshayTensor.stack()
AlexandraTensor = AlexandraTensor.stack()
AliaTensor = AliaTensor.stack()
CourtneyTensor = CourtneyTensor.stack()

# %%
AkshayLabels = tf.ones(AkhshayTensor.shape[0]*2, 1) - 1
AlexandraLabels = tf.ones(AlexandraTensor.shape[0]*2, 1) * 2 - 1
AliaLabels = tf.ones(AliaTensor.shape[0]*2, 1)*3 - 1
CourtneyLabels = tf.ones(CourtneyTensor.shape[0]*2, 1)*4 - 1

# %%
AugAk = data_augmentation(AkhshayTensor)
AugAlex = data_augmentation(AlexandraTensor)
AugAlia = data_augmentation(AliaTensor)
AugCourtney = data_augmentation(CourtneyTensor)

# %%
AkFinal = tf.concat([AkhshayTensor, AugAk], axis = 0)
AlexFinal = tf.concat([AlexandraTensor, AugAlex], axis = 0)
AliaFinal = tf.concat([AliaTensor, AugAlia], axis = 0)
CourtneyFinal = tf.concat([CourtneyTensor, AugCourtney], axis = 0)

# %%
AkImgDataset = tf.data.Dataset.from_tensor_slices((AkFinal, AkshayLabels))
AlexImgDataset = tf.data.Dataset.from_tensor_slices((AlexFinal, AlexandraLabels))
AliaImgDataset = tf.data.Dataset.from_tensor_slices((AliaFinal, AliaLabels))
CourtneyImgDataset = tf.data.Dataset.from_tensor_slices((CourtneyFinal, CourtneyLabels))

# %%
Aksplitindex  = int(0.8*(len(AkFinal)))
Alexsplitindex = int(0.8*(len(AlexFinal)))
Aliasplitindex = int(0.8*(len(AliaFinal)))
Courtneysplitindex = int(0.8*(len(CourtneyFinal)))

AkImgDataset = AkImgDataset.shuffle(buffer_size=len(AkFinal), seed=1)
Aktrain_dataset = AkImgDataset.take(Aksplitindex)
Akval_dataset = AkImgDataset.skip(Aksplitindex)

AlexImgDataset = AlexImgDataset.shuffle(buffer_size= len(AlexFinal), seed = 1)
Alextrain_dataset = AlexImgDataset.take(Alexsplitindex)
Alexval_dataset = AlexImgDataset.skip(Alexsplitindex)

AliaImgDataset = AliaImgDataset.shuffle(buffer_size= len(AliaFinal), seed = 1)
Aliatrain_dataset = AliaImgDataset.take(Aliasplitindex)
Aliaval_dataset = AliaImgDataset.skip(Aliasplitindex)

CourtneyImgDataset = CourtneyImgDataset.shuffle(buffer_size= len(CourtneyFinal), seed = 1)
Courtneytrain_dataset = CourtneyImgDataset.take(Courtneysplitindex)
Courtneyval_dataset = CourtneyImgDataset.skip(Courtneysplitindex)

train_dataset = Aktrain_dataset.concatenate(Alextrain_dataset).concatenate(Aliatrain_dataset).concatenate(Courtneytrain_dataset)
val_dataset = Akval_dataset.concatenate(Alexval_dataset).concatenate(Aliaval_dataset).concatenate(Courtneyval_dataset)

# %%
train_dataset = train_dataset.batch(32)
val_dataset = val_dataset.batch(32)

# %% [markdown]
# ## Utility Functions

# %%
from pathlib import Path
from time import strftime

def get_run_logdir(root_logdir='FaceRecogLogs'):
  return Path(root_logdir)/strftime('rin_%Y_%m_%d_%H_%M_%S')

logdir = get_run_logdir()

# %%
import os


model_dir = 'model'
os.makedirs(model_dir, exist_ok=True)

model_path = os.path.join(model_dir, 'FaceRecognition_best.keras')

# %% [markdown]
# ## Model

# %%
class FaceDetectionCNN(tf.keras.Model):
  def __init__(self, **kwargs):
    super().__init__(**kwargs)
    self.preprocess_inputs_ = tf.keras.applications.inception_v3.preprocess_input
    self.base_model = tf.keras.applications.InceptionV3(weights = 'imagenet', include_top=False)
    self.EmbeddingNet_ = tf.keras.Sequential([
                                             tf.keras.layers.Dense(256, activation = tf.keras.activations.relu,
                                                                   kernel_regularizer = tf.keras.regularizers.l2(0.1),
                                                                   kernel_initializer = tf.keras.initializers.he_normal()),
                                             tf.keras.layers.BatchNormalization(),                      
                                             tf.keras.layers.Dense(256, activation = tf.keras.activations.relu,
                                                                   kernel_regularizer = tf.keras.regularizers.l2(0.1)),
                                             tf.keras.layers.Dropout(0.2),
                                             tf.keras.layers.Dense(128, activation = tf.keras.activations.relu,
                                                                   kernel_initializer = tf.keras.initializers.glorot_normal()),
                                             tf.keras.layers.BatchNormalization(),                      
                                             tf.keras.layers.Dropout(0.2),                      
                                             tf.keras.layers.Dense(64, activation = tf.keras.activations.relu,
                                                                   kernel_regularizer = tf.keras.regularizers.l2(0.1)),
                                             tf.keras.layers.Dropout(0.2),
                                             tf.keras.layers.Dense(32, activation = tf.keras.activations.relu)
                                             ])
    self.GlobAvg_ = tf.keras.layers.GlobalAveragePooling2D()
    self.classifier = tf.keras.layers.Dense(4, activation = 'softmax')

  def call(self, inputs, training = False):
    x = inputs
    processed_inputs = self.preprocess_inputs_(x)
    x = self.base_model(processed_inputs, training = training)
    x = self.GlobAvg_(x)
    embeddings = self.EmbeddingNet_(x, training = training)
    return self.classifier(embeddings)
  
  def get_config(self):
    base_config = super().get_config()
    base_config.update({'preprocess_inputs_': self.preprocess_inputs_ ,
                        'base_model' : self.base_model})
    return base_config

# %%
class DelayModelGraphs(tf.keras.callbacks.Callback):
    def __init__(self, unfreeze_epoch,new_lr = None, **kwargs):
        super().__init__(**kwargs)
        self.unfreeze_epoch = unfreeze_epoch
        self.DelayedLr_ = new_lr

    def on_epoch_begin(self, epoch , logs = None):
        if epoch == self.unfreeze_epoch:
            self.model.base_model.trainable = True
            if self.DelayedLr_ is not(None):
              self.model.base_model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = self.DelayedLr_))
            print('Unfreezing base model')

class UpdateCurrentEpoch(tf.keras.callbacks.Callback):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.current_epoch = 0

    def on_epoch_begin(self, epoch, logs = None):
        self.current_epoch = epoch


class TensorBoardFeatureMapVisualizer(tf.keras.callbacks.Callback):
    def __init__(self,  log_dir,frequency = 1,**kwargs):
        super().__init__(**kwargs)
        self.freq = frequency
        self.writer = tf.summary.create_file_writer(log_dir)

    def on_train_begin(self, logs = None):
        base_model = self.model.base_model
        self.intermediate_model = tf.keras.Model(inputs = base_model.inputs,
                                                 outputs = [layer.output for layer in base_model.layers if isinstance(layer, tf.keras.layers.Conv2D)])
        self.subject_image = next(iter(train_dataset.take(1)))[0][0:1]

    def on_epoch_begin(self, epoch, logs=None):
        if epoch%self.freq == 0:
            feature_maps = self.intermediate_model.predict(self.subject_image)
            with self.writer.as_default():
                for i , feature_map in enumerate(feature_maps):
                    feature_map = tf.reduce_mean(feature_map, axis = -1, keepdims = True)
                    tf.summary.image('FeatureMap_{}'.format(i), feature_map, step = epoch)

# %% [markdown]
# ## HyperModel Tuner

# %%
import keras_tuner as kt

class HyperModel(kt.HyperModel):
    def build(self, hp):
        learning_rate = hp.Float('learning_rate', min_value = 1e-4, max_value = 1e-2, sampling= 'log')
        optimizer = hp.Choice('optimizer', values = ['adam', 'sgd'])
        if optimizer=='adam':
            optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate)
        else :
            optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate , momentum = 0.9)    
        model = FaceDetectionCNN()
        model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
                      optimizer = optimizer,
                      metrics = ['accuracy'])
        return model

# %%
HyperModelTuner = kt.BayesianOptimization(hypermodel = HyperModel(),
                                          objective= 'accuracy',
                                          max_trials= 5,
                                          directory = 'FaceDetetcion Hypermodel',
                                          project_name = 'FaceRecogTunerTrials',
                                          seed = 42)
# Out:
# Reloading Tuner from FaceDetetcion Hypermodel\FaceRecogTunerTrials\tuner0.json

# %%
HyperModelTuner.search(train_dataset ,
                        epochs = 8,
                        validation_data = val_dataset,
                        callbacks = [DelayModelGraphs(unfreeze_epoch=4)] )

# %%
HyperModelTuner.get_best_hyperparameters()[0].values
# Out:
# {'learning_rate': 0.0009887195863122636, 'optimizer': 'adam'}

# %%
lr = HyperModelTuner.get_best_hyperparameters()[0].values['learning_rate']
optm = HyperModelTuner.get_best_hyperparameters()[0].values['optimizer']

# %%
model = FaceDetectionCNN()
model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
              metrics =['accuracy'])

# %%
history = model.fit(train_dataset , epochs = 50 , callbacks = [TensorBoardFeatureMapVisualizer(str(logdir)),
                                                               DelayModelGraphs(15),
                                                               tf.keras.callbacks.ModelCheckpoint(filepath = model_path,
                                                                                                  monitor = 'accuracy',
                                                                                                  save_weights_only = False,
                                                                                                  save_best_only = True,
                                                                                                  verbose = 1),
                                                               tf.keras.callbacks.TensorBoard(str(logdir),
                                                                                              histogram_freq = 1,
                                                                                              write_graph = True,
                                                                                              write_images = True)],
                    validation_data = val_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4126 - loss: 3.1679
# Epoch 1: accuracy improved from -inf to 0.30905, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 0.4091 - loss: 3.1591 - val_accuracy: 0.3246 - val_loss: 2.3993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4061 - loss: 2.3606
# Epoch 2: accuracy improved from 0.30905 to 0.32119, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 0.4033 - loss: 2.3548 - val_accuracy: 0.3246 - val_loss: 1.9309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3230 - loss: 1.9553
# Epoch 3: accuracy did not improve from 0.32119
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 5s/step - accuracy: 0.3221 - loss: 1.9513 - val_accuracy: 0.3246 - val_loss: 1.6892
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3736 - loss: 1.7772
# Epoch 4: accuracy improved from 0.32119 to 0.33996, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 131s 5s/step - accuracy: 0.3725 - loss: 1.7734 - val_accuracy: 0.3246 - val_loss: 1.5820
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3216 - loss: 1.6032
# Epoch 5: accuracy improved from 0.33996 to 0.36424, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.3230 - loss: 1.5994 - val_accuracy: 0.3246 - val_loss: 1.5656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2322 - loss: 1.7486
# Epoch 6: accuracy improved from 0.36424 to 0.36976, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 132s 5s/step - accuracy: 0.2368 - loss: 1.7412 - val_accuracy: 0.2807 - val_loss: 80.8283
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1748 - loss: 1.8565
# Epoch 7: accuracy did not improve from 0.36976
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.1808 - loss: 1.8478 - val_accuracy: 0.2544 - val_loss: 1.6825
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2930 - loss: 1.7992
# Epoch 8: accuracy improved from 0.36976 to 0.46247, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 125s 4s/step - accuracy: 0.2986 - loss: 1.7915 - val_accuracy: 0.2807 - val_loss: 1.8321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2132 - loss: 1.9502
# Epoch 9: accuracy did not improve from 0.46247
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 125s 4s/step - accuracy: 0.2211 - loss: 1.9422 - val_accuracy: 0.2807 - val_loss: 14.5265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2385 - loss: 2.0742
# Epoch 10: accuracy improved from 0.46247 to 0.48124, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.2466 - loss: 2.0632 - val_accuracy: 0.2807 - val_loss: 99.6505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2948 - loss: 1.9223
# Epoch 11: accuracy improved from 0.48124 to 0.48344, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.3010 - loss: 1.9139 - val_accuracy: 0.2807 - val_loss: 14.6288
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2648 - loss: 2.0498
# Epoch 12: accuracy did not improve from 0.48344
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.2712 - loss: 2.0426 - val_accuracy: 0.1140 - val_loss: 2118295.5000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2722 - loss: 2.0426
# Epoch 13: accuracy did not improve from 0.48344
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 132s 5s/step - accuracy: 0.2786 - loss: 2.0356 - val_accuracy: 0.2807 - val_loss: 691667.8125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3801 - loss: 1.9401
# Epoch 14: accuracy improved from 0.48344 to 0.54415, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 183s 6s/step - accuracy: 0.3855 - loss: 1.9321 - val_accuracy: 0.2807 - val_loss: 20756.4297
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3048 - loss: 2.0653
# Epoch 15: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 136s 5s/step - accuracy: 0.3118 - loss: 2.0578 - val_accuracy: 0.2807 - val_loss: 84.2699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Unfreezing base model
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2770 - loss: 2.2947
# Epoch 16: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 146s 5s/step - accuracy: 0.2832 - loss: 2.2818 - val_accuracy: 0.2807 - val_loss: 43.6403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.3477 - loss: 1.9465
# Epoch 17: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 188s 7s/step - accuracy: 0.3534 - loss: 1.9385 - val_accuracy: 0.2807 - val_loss: 5.0078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2964 - loss: 2.0625
# Epoch 18: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 186s 6s/step - accuracy: 0.3031 - loss: 2.0524 - val_accuracy: 0.2807 - val_loss: 2.0596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2434 - loss: 2.0588
# Epoch 19: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 187s 6s/step - accuracy: 0.2506 - loss: 2.0497 - val_accuracy: 0.2807 - val_loss: 54.6097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.2433 - loss: 1.9077
# Epoch 20: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 184s 6s/step - accuracy: 0.2511 - loss: 1.9007 - val_accuracy: 0.2807 - val_loss: 85.2922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3535 - loss: 2.0979
# Epoch 21: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 158s 6s/step - accuracy: 0.3586 - loss: 2.0902 - val_accuracy: 0.2807 - val_loss: 8010.5371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2587 - loss: 1.9579
# Epoch 22: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 157s 5s/step - accuracy: 0.2618 - loss: 1.9532 - val_accuracy: 0.3246 - val_loss: 22558.6328
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3758 - loss: 1.8467
# Epoch 23: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 156s 5s/step - accuracy: 0.3796 - loss: 1.8401 - val_accuracy: 0.1140 - val_loss: 711.5444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4222 - loss: 1.8442
# Epoch 24: accuracy did not improve from 0.54415
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 140s 5s/step - accuracy: 0.4257 - loss: 1.8401 - val_accuracy: 0.1140 - val_loss: 44.0347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3939 - loss: 2.0157
# Epoch 25: accuracy improved from 0.54415 to 0.54636, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.3989 - loss: 2.0067 - val_accuracy: 0.2807 - val_loss: 778.8481
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3842 - loss: 2.3582
# Epoch 26: accuracy did not improve from 0.54636
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.3896 - loss: 2.3473 - val_accuracy: 0.1140 - val_loss: 265727.7500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4059 - loss: 2.1787
# Epoch 27: accuracy did not improve from 0.54636
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - accuracy: 0.4100 - loss: 2.1747 - val_accuracy: 0.3246 - val_loss: 2.4365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4372 - loss: 2.4230
# Epoch 28: accuracy improved from 0.54636 to 0.56181, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 150s 5s/step - accuracy: 0.4413 - loss: 2.4121 - val_accuracy: 0.2807 - val_loss: 2.9374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2778 - loss: 2.5690
# Epoch 29: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - accuracy: 0.2836 - loss: 2.5548 - val_accuracy: 0.3246 - val_loss: 2.1606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3537 - loss: 2.3101
# Epoch 30: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.3591 - loss: 2.3048 - val_accuracy: 0.2807 - val_loss: 465.9479
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.3191 - loss: 2.4048
# Epoch 31: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 145s 5s/step - accuracy: 0.3236 - loss: 2.3975 - val_accuracy: 0.3026 - val_loss: 790.9548
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1856 - loss: 2.6119
# Epoch 32: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 141s 5s/step - accuracy: 0.1896 - loss: 2.5999 - val_accuracy: 0.1140 - val_loss: 340.0389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3618 - loss: 2.0317
# Epoch 33: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.3669 - loss: 2.0281 - val_accuracy: 0.2807 - val_loss: 699.7862
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3616 - loss: 2.0936
# Epoch 34: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 142s 5s/step - accuracy: 0.3665 - loss: 2.0863 - val_accuracy: 0.2807 - val_loss: 548.7703
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3172 - loss: 1.9808
# Epoch 35: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 143s 5s/step - accuracy: 0.3225 - loss: 1.9760 - val_accuracy: 0.2807 - val_loss: 506878.6250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2178 - loss: 2.1416
# Epoch 36: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 144s 5s/step - accuracy: 0.2239 - loss: 2.1315 - val_accuracy: 0.2807 - val_loss: 30990.9922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2873 - loss: 2.2679
# Epoch 37: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 131s 5s/step - accuracy: 0.2938 - loss: 2.2578 - val_accuracy: 0.3246 - val_loss: 1354.1832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4146 - loss: 1.8755
# Epoch 38: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 133s 5s/step - accuracy: 0.4187 - loss: 1.8719 - val_accuracy: 0.2939 - val_loss: 2.2607
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3646 - loss: 1.8871
# Epoch 39: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 0.3702 - loss: 1.8825 - val_accuracy: 0.2807 - val_loss: 1351.6606
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3644 - loss: 1.9649
# Epoch 40: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 0.3707 - loss: 1.9560 - val_accuracy: 0.2807 - val_loss: 1832.2299
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2587 - loss: 2.5271
# Epoch 41: accuracy did not improve from 0.56181
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 127s 4s/step - accuracy: 0.2636 - loss: 2.5169 - val_accuracy: 0.3246 - val_loss: 14720.3447
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3877 - loss: 1.9986
# Epoch 42: accuracy improved from 0.56181 to 0.56623, saving model to model\FaceRecognition_best.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 133s 5s/step - accuracy: 0.3937 - loss: 1.9917 - val_accuracy: 0.3246 - val_loss: 2618.1411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3644 - loss: 2.2204
# Epoch 43: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 132s 5s/step - accuracy: 0.3706 - loss: 2.2105 - val_accuracy: 0.2807 - val_loss: 328.4822
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2624 - loss: 2.1040
# Epoch 44: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.2666 - loss: 2.0992 - val_accuracy: 0.2807 - val_loss: 2.2621
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3637 - loss: 2.0507
# Epoch 45: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.3686 - loss: 2.0430 - val_accuracy: 0.2807 - val_loss: 2.0155
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4122 - loss: 1.8333
# Epoch 46: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.4171 - loss: 1.8289 - val_accuracy: 0.2807 - val_loss: 2.1453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3404 - loss: 2.1235
# Epoch 47: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 123s 4s/step - accuracy: 0.3446 - loss: 2.1186 - val_accuracy: 0.2763 - val_loss: 26.2504
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2805 - loss: 2.2705
# Epoch 48: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.2871 - loss: 2.2605 - val_accuracy: 0.2807 - val_loss: 2.1473
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3511 - loss: 2.2236
# Epoch 49: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 123s 4s/step - accuracy: 0.3563 - loss: 2.2177 - val_accuracy: 0.3246 - val_loss: 2.2020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3480 - loss: 2.3006
# Epoch 50: accuracy did not improve from 0.56623
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.3528 - loss: 2.2943 - val_accuracy: 0.2807 - val_loss: 25.8544

# %%
pd.DataFrame(history.history).plot(figsize = (8,5), xlim = [0,50] , ylim = [0,1], grid = True , xlabel = 'Epoch', 
                                   style = ['r--', 'r--.', 'b-', 'b-*'])
plt.show()

# %% [markdown]
# ## Model Analysis and Scope
# As we can see my model seems to have not performed well , but thats because I chose a learning rate thats quite low . and my PC isnt powerful enough to process these images as fast as I would typically want it to. However I did extract the best model weights by a checkpoint . I can use the best model to make predcitions.

# %% [markdown]
# ## Convolutions

# %% [markdown]
# I implemented a callback that allows me to look at all the feature maps of an image and look at all the different changes that it goesthrough throughout different epochs.
# >Observations:
# The model is working perfectly fine but the lack of a well defined dataset makes it hard to actually learn from the features.
# Here are the extracted feature maps during some of the epochs . I have used TensorBoard for visualisation here:
#
#
# ![Screenshot 2024-06-05 172524.png](<attachment:Screenshot 2024-06-05 172524.png>)
# ![Screenshot 2024-06-05 172540.png](<attachment:Screenshot 2024-06-05 172540.png>)
#
# As you can see the features are being processed appropriately ,  but the lack of proper samples and correct distribution has resulted in bad performance

# %% [markdown]
# There are also certain images where the features arent properly localised because of the lack of a bounding box :
#
# ![Screenshot 2024-06-05 172546.png](<attachment:Screenshot 2024-06-05 172546.png>)

# %% [markdown]
# ## Learning Evaluation

# %% [markdown]
# ![Screenshot 2024-06-05 172511.png](<attachment:Screenshot 2024-06-05 172511.png>)
#
# As you can see the model has not generised well .But there are still things that I learned from it .
#
# My dataset consists of faces and other irrelevant information along with it this cause the model.EmbeddingNet to produce 32 dimensional embeddings which mostly contain irrelevant values since the model is unable to capture and focus on the highes amount of relevant variance subsamples.

# %% [markdown]
# ##Learning Rate and Epoch vs Loss curves
#
# ![image.png](attachment:image.png)
#
# I decided not to change the learning rate after unfreezing the imported InceptionV3 model mostly because of the lack of computational power.
#
# ![image-2.png](attachment:image-2.png)
#
# And as a result there are spikes in the loss curves mostly because the model is oscillating from the optimal weight kernels and producing results that deviate from the desired minima periodically.

# %% [markdown]
# ## Analysis
#
# I have successfully implemented a face recognition/detection model using transfer learning even though the results arent promising.
#
# With a proper dataset the model would generalise well and would produce accuracy which is respectable for deployment.
# The dataset consists of 4 people (faces) and I have augmented the data to increase the sample space.
# I then added a Dense net to classify from the convolved data and make predictions.
